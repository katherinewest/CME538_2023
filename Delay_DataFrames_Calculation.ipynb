# %%
#pip install openpyxl

# %%
# Import 3rd party libraries
import os
import json
import pandas as pd
import xml.etree.ElementTree as ET
import datetime as dt

# %% [markdown]
# Task Status:
# TTC Subway-
# TTC Bus- Done but graph looks weird
# Ottawa Bus- Have a dataframe with arrival/ departure times (still need to calculate delay)
# Go Train- Need to reformat file?

# %% [markdown]
# TORONTO SUBWAY DATA (TTC)

# %%
#Pulling ttc subway files from 2018 onward TODO: Should we include back to 2014?
ttc_subway_files = [file for file in os.listdir() if 'ttc-subway-delay-data-20' in file]

dfs=[]

# Loop through the selected subway files, create individual dataframes for each sheet, and add dfs to a list 
for file in ttc_subway_files:
    sheet_names = pd.ExcelFile(file).sheet_names
    for sheet in sheet_names:
        temp_df = pd.read_excel(file, sheet_name= sheet)
        dfs.append(temp_df)
    
# Concatenate all individual DataFrames from the list into a single DataFrame
ttc_subway_df = pd.concat(dfs, ignore_index=True)

# %%
#ttc_subway_df.plot(x= "Date", y='Min Delay')
print(ttc_subway_df.info())
ttc_subway_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108004 entries, 0 to 108003
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       108004 non-null  datetime64[ns]
#  1   Time       108004 non-null  object
#  2   Day        108004 non-null  object
#  3   Station    108004 non-null  object
#  4   Code       108004 non-null  object
#  5   Min Delay  108004 non-null  int64
#  6   Min Gap    108004 non-null  int64
#  7   Bound      79240 non-null   object
#  8   Line       107675 non-null  object
#  9   Vehicle    108004 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(6)
# memory usage: 8.2+ MB
# None
#         Date   Time     Day                Station   Code  Min Delay  Min Gap  \
# 0 2018-01-01  00:29  Monday  SHEPPARD WEST STATION  MUATC         10       15
# 1 2018-01-01  01:07  Monday         DUNDAS STATION  MUNCA          0        0
# 2 2018-01-01  01:22  Monday         MUSEUM STATION   MUSC          0        0
# 3 2018-01-01  01:28  Monday              BAY LOWER   EUOE          0        0
# 4 2018-01-01  01:39  Monday         MUSEUM STATION    MUO          6       11
#
#   Bound Line  Vehicle
# 0     N   YU     5986
# 1   NaN   YU        0
# 2     N   YU     5751
# 3   NaN   BD     5222
# 4     S   YU     5781

# %%
ttc_subway_df.plot(x= "Date", y='Min Delay')
# Out:
# <Axes: xlabel='Date'>

# %%
#Exporting dataframe to CSV
ttc_subway_df.to_csv('ttc_subway_df.csv', index='False')

# %% [markdown]
# TORONTO BUS DATA (TTC)

# %%
#TORONTO BUS
ttc_bus_files= ['ttc-bus-delay-data-2018.xlsx','ttc-bus-delay-data-2019.xlsx', 
                 'ttc-bus-delay-data-2020.xlsx','ttc-bus-delay-data-2021.xlsx',
                 'ttc-bus-delay-data-2022.xlsx','ttc-bus-delay-data-2023.xlsx']

dfs=[]
# Loop through the selected subway files, create individual dataframes, and add dfs to a list 
for file in ttc_bus_files:
    sheet_names = pd.ExcelFile(file).sheet_names
    for sheet in sheet_names:
        temp_df = pd.read_excel(file, sheet_name= sheet, engine='openpyxl')
        dfs.append(temp_df)
    
# Concatenate all individual DataFrames from the list into a single DataFrame
ttc_bus_df = pd.concat(dfs, ignore_index=True)

# %%
#Cleaning DataFrame
ttc_bus_df['Report Date'].fillna(ttc_bus_df['Date'], inplace=True)
ttc_bus_df['Min Gap'].fillna(ttc_bus_df['Gap'], inplace=True)
ttc_bus_df['Min Delay'].fillna(ttc_bus_df['Delay'], inplace=True)
ttc_bus_df[' Min Delay'].fillna(ttc_bus_df['Delay'], inplace=True)
ttc_bus_df['Route'].fillna(ttc_bus_df['Line'], inplace=True)

# %%
ttc_bus_df.drop(columns=['Date', 'Incident ID', ' Min Delay', 'Delay', 'Gap', 'Line', 'Bound', 'Unnamed: 10'], inplace = True)

# %%
# ttc_bus_df[ttc_bus_df['Unnamed: 10'].notnull() == True]
print(ttc_bus_df.info())
ttc_bus_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313460 entries, 0 to 313459
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Report Date  313460 non-null  datetime64[ns]
#  1   Route        312339 non-null  object
#  2   Time         313460 non-null  object
#  3   Day          313460 non-null  object
#  4   Location     313154 non-null  object
#  5   Incident     312525 non-null  object
#  6   Min Delay    307525 non-null  float64
#  7   Min Gap      312570 non-null  float64
#  8   Direction    281162 non-null  object
#  9   Vehicle      286529 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(6)
# memory usage: 23.9+ MB
# None
#   Report Date Route      Time     Day            Location            Incident  \
# 0  2018-01-01   165  00:17:00  Monday          Wilson Stn          Mechanical
# 1  2018-01-01   706  00:20:00  Monday   Birchmount Garage  Utilized Off Route
# 2  2018-01-01    28  00:30:00  Monday  Davisville Station       Investigation
# 3  2018-01-01    12  00:55:00  Monday     Kennedy Station          Mechanical
# 4  2018-01-01    72  00:55:00  Monday        Pape Station          Mechanical
#
#    Min Delay  Min Gap Direction  Vehicle
# 0       10.0     20.0       W/B   1291.0
# 1        1.0      1.0       S/B   8123.0
# 2       30.0     60.0       S/B   8306.0
# 3       22.0     44.0       S/B   7777.0
# 4       18.0     36.0       NaN   7787.0

# %%
ttc_bus_df.plot(x= "Report Date", y='Min Delay')
#This graph looks suspicious
# Out:
# <Axes: xlabel='Report Date'>

# %%
#Exporting dataframe to CSV
ttc_bus_df.to_csv('ttc_bus_df.csv', index='False')

# %% [markdown]
# OTTAWA BUS DATA (OC TRANSPORT)

# %%
#OTTAWA BUS??
#Import OCTransport data- Ottawa
oct_file = json.load(open('octranspo_output.json', encoding='utf8'))

# %%
#Get values from JSON file to Dataframe
#Data pulled on Nov 7, 2023 at 17:06:00 <--ending time 
#Scale time 1 sec  per call
rows=[]
for bus_stop in oct_file:
    stop_no = oct_file[bus_stop]['GetRouteSummaryForStopResult']["StopNo"]
    #Format changes after this point and breaks code
    if bus_stop == '7523':
        break
    stop_description = oct_file[bus_stop]['GetRouteSummaryForStopResult']["StopDescription"]
    #print(bus_stop)
    
    #Added to fix issue with for loop when only one route number in "Routes"
    if isinstance(oct_file[bus_stop]['GetRouteSummaryForStopResult']['Routes']['Route'], dict):
        routes = [oct_file[bus_stop]['GetRouteSummaryForStopResult']['Routes']['Route']]
    else:
        routes = oct_file[bus_stop]['GetRouteSummaryForStopResult']['Routes']['Route']
        
    for route_no in routes:
        #print(route_no)
        #print(' ')
        route_number = route_no['RouteNo']
        for trip in route_no['Trips']['Trip']: 
            #print(trip)
            longitude = trip['Longitude']
            latitude = trip['Latitude']
            gps_speed = trip['GPSSpeed']
            trip_start_time = trip['TripStartTime']
            adj_sched_time = trip['AdjustedScheduleTime']
            adj_age = trip['AdjustmentAge']
        
            rows.append({
                'bus_stop': bus_stop,
                'stop_code': stop_no,
                'stop_description': stop_description,
                'route_number': route_number,
                'longitude': longitude,
                'latitude': latitude,
                'gps_speed': gps_speed,
                'trip_start_time': trip_start_time,
                'adj_sched_time': adj_sched_time,
                'adj_age': adj_age
            })

bus_info = pd.DataFrame(rows)

bus_info['stop_code'] = bus_info['stop_code'].astype('int')
bus_info['trip_start_time'] = pd.to_datetime(bus_info['trip_start_time'], format='%H:%M').dt.time

bus_info.head()
# Out:
#   bus_stop  stop_code          stop_description route_number  \
# 0     6941       4055  CHESTERTON / ASSINIBOINE          111
# 1     6941       4055  CHESTERTON / ASSINIBOINE          111
# 2     6941       4055  CHESTERTON / ASSINIBOINE          111
# 3      572       4055  CHESTERTON / ASSINIBOINE          111
# 4      572       4055  CHESTERTON / ASSINIBOINE          111
#
#             longitude            latitude gps_speed trip_start_time  \
# 0  -75.72068887007863   45.35138501619038        18        14:43:00
# 1   -75.7063585478684  45.375254269303944        12        14:58:00
# 2                                                          15:12:00
# 3  -75.72068887007863   45.35138501619038        18        14:43:00
# 4   -75.7063585478684  45.375254269303944        12        14:58:00
#
#   adj_sched_time adj_age
# 0              1    0.93
# 1             14    0.65
# 2             28      -1
# 3              1    0.93
# 4             14    0.65

# %%
bus_info.shape
# Out:
# (4201, 10)

# %%
#Creating a loop to account for delay in call time
index= len(bus_info)-1
temp_stop = bus_info.iloc[index]['bus_stop']
temp_time = pd.to_datetime('17:06:00')

while index >= 0:
    if temp_stop == bus_info.iloc[index]['bus_stop']:
        bus_info.loc[index, 'call_time'] = temp_time
    else:
        temp_stop = bus_info.iloc[index]['bus_stop']
        temp_time = temp_time - pd.Timedelta(seconds=1)
        bus_info.loc[index, 'call_time'] = temp_time
    
    index= index-1  

#Create a column 'est_arrival_time' which is equal to the call time 
bus_info
# Out:
#      bus_stop  stop_code          stop_description route_number  \
# 0        6941       4055  CHESTERTON / ASSINIBOINE          111
# 1        6941       4055  CHESTERTON / ASSINIBOINE          111
# 2        6941       4055  CHESTERTON / ASSINIBOINE          111
# 3         572       4055  CHESTERTON / ASSINIBOINE          111
# 4         572       4055  CHESTERTON / ASSINIBOINE          111
# ...       ...        ...                       ...          ...
# 4196     4912       4149         FIELDING / RANKIN          290
# 4197     4912       4149         FIELDING / RANKIN          290
# 4198     4921       4149         FIELDING / RANKIN          290
# 4199     4921       4149         FIELDING / RANKIN          290
# 4200     4921       4149         FIELDING / RANKIN          290
#
#                longitude            latitude gps_speed trip_start_time  \
# 0     -75.72068887007863   45.35138501619038        18        14:43:00
# 1      -75.7063585478684  45.375254269303944        12        14:58:00
# 2                                                             15:12:00
# 3     -75.72068887007863   45.35138501619038        18        14:43:00
# 4      -75.7063585478684  45.375254269303944        12        14:58:00
# ...                  ...                 ...       ...             ...
# 4196                                                          16:06:00
# 4197                                                          16:35:00
# 4198  -75.68109829325071   45.37823298279668        20        15:41:00
# 4199                                                          16:06:00
# 4200                                                          16:35:00
#
#      adj_sched_time adj_age           call_time
# 0                 1    0.93 2023-11-29 16:42:39
# 1                14    0.65 2023-11-29 16:42:39
# 2                28      -1 2023-11-29 16:42:39
# 3                 1    0.93 2023-11-29 16:42:40
# 4                14    0.65 2023-11-29 16:42:40
# ...             ...     ...                 ...
# 4196             41      -1 2023-11-29 17:05:59
# 4197             70      -1 2023-11-29 17:05:59
# 4198             15    0.30 2023-11-29 17:06:00
# 4199             41      -1 2023-11-29 17:06:00
# 4200             70      -1 2023-11-29 17:06:00
#
# [4201 rows x 11 columns]

# %%
bus_info.shape
# Out:
# (4201, 11)

# %%
#Create stops dataframe
stops = pd.read_csv('google_transit/stops.txt', delimiter=',')
#Only want last three number in stop_id
# stops['stop_id'] = stops['stop_id'].apply(lambda x: x[-3:])
stops_reduced= stops[['stop_id', 'stop_code']]
stops_reduced.head()
# Out:
#   stop_id  stop_code
# 0   AA010     8767.0
# 1   AA020     6859.0
# 2   AA030     7001.0
# 3   AA035     8762.0
# 4   AA040     7000.0

# %%
stops_reduced.shape
# Out:
# (5816, 2)

# %%
#Create stop times dataframe
stop_times = pd.read_csv('google_transit\stop_times.txt', delimiter=',')
#Only want last three number in stop_id
#stop_times['stop_id'] = stop_times['stop_id'].apply(lambda x: x[-3:])

#Trying to convert to datetimes
arrival_time = stop_times['arrival_time'].to_list()
print(arrival_time[0:5])

arrival_time_collected = []
for index in arrival_time:
    time = index.split(':')
    hour = int(time[0])
    if hour > 23:
        hour = hour - 24
    minutes= int(time[1])
    seconds= int(time[2])
    arrival_time_collected.append(pd.to_datetime(f"{hour:02d}:{minutes:02d}:{seconds:02d}"))

stop_times["arrival_datetime"] = arrival_time_collected

stop_times["start_time"] = stop_times["arrival_time"]

stop_times.shape

# split_times = [x.strip() for x in arrival_time.split(':')] #Split by space
# print(split_times)
# 
# hours=str(split_times[0::2])
# minutes= split_times[1::2]
# seconds= split_times[2::2]
# print(hours)
# 
# hours_final = [(hours[x].split(' ')[-1:]) for x in hours]
# print(hours_final)
# # print(split_times[0].split(' ')[-1:])
# 
# if int(arrival_time.split(':')[0]) > 23:
#     stop_times['arrival_time'] = arrival_time_str.replace(arrival_time_str.split(':')[0], '00', 1)
# 
# stop_times['arrival_time'] = pd.to_datetime(stop_times['arrival_time'], format='%H:%M:%S').dt.time
# 
# #NOTE: Departure time and arrival time are the same
stop_times_reduced= stop_times[['stop_id', "start_time", 'stop_sequence', "arrival_datetime"]]
# 
# stop_times_reduced.head()
# Out:
# ['08:56:00', '08:57:00', '08:57:00', '08:57:00', '08:58:00']

# %%
stop_times_reduced.shape
# Out:
# (1099287, 4)

# %%
#Merge stop times and stops on stop id
stop_times_merged = pd.merge(left= stop_times_reduced, right= stops_reduced, on='stop_id')
stop_times_merged.head(20)
# Out:
#    stop_id start_time  stop_sequence    arrival_datetime  stop_code
# 0    WR161   08:56:00              1 2023-11-29 08:56:00     5900.0
# 1    WR161   07:12:00              1 2023-11-29 07:12:00     5900.0
# 2    WR161   05:39:00             16 2023-11-29 05:39:00     5900.0
# 3    WR161   06:36:00             16 2023-11-29 06:36:00     5900.0
# 4    WR235   08:57:00              2 2023-11-29 08:57:00     6278.0
# 5    WR235   15:29:00             76 2023-11-29 15:29:00     6278.0
# 6    WR235   07:13:00              2 2023-11-29 07:13:00     6278.0
# 7    WR235   05:40:00             17 2023-11-29 05:40:00     6278.0
# 8    WR235   06:37:00             17 2023-11-29 06:37:00     6278.0
# 9    WR235   16:36:00             25 2023-11-29 16:36:00     6278.0
# 10   WR235   17:08:00             25 2023-11-29 17:08:00     6278.0
# 11   WR235   17:42:00             25 2023-11-29 17:42:00     6278.0
# 12   WR235   18:27:00             25 2023-11-29 18:27:00     6278.0
# 13   WR245   08:57:00              3 2023-11-29 08:57:00     6281.0
# 14   WR245   07:13:00              3 2023-11-29 07:13:00     6281.0
# 15   WR245   05:40:00             18 2023-11-29 05:40:00     6281.0
# 16   WR245   06:37:00             18 2023-11-29 06:37:00     6281.0
# 17   WR249   08:57:00              4 2023-11-29 08:57:00     6283.0
# 18   WR249   07:13:00              4 2023-11-29 07:13:00     6283.0
# 19   WR249   05:40:00             19 2023-11-29 05:40:00     6283.0

# %%
stop_times_merged.shape
# Out:
# (1099287, 5)

# %%
bus_info_with_times= pd.merge(left=bus_info, right=stop_times_merged, left_on=['stop_code', "trip_start_time"], right_on=['stop_code', "start_time"], how='left')
bus_info_with_times.head(100)
# Out:
#    bus_stop  stop_code          stop_description route_number  \
# 0      6941       4055  CHESTERTON / ASSINIBOINE          111
# 1      6941       4055  CHESTERTON / ASSINIBOINE          111
# 2      6941       4055  CHESTERTON / ASSINIBOINE          111
# 3       572       4055  CHESTERTON / ASSINIBOINE          111
# 4       572       4055  CHESTERTON / ASSINIBOINE          111
# ..      ...        ...                       ...          ...
# 95     3636       4055  CHESTERTON / ASSINIBOINE          111
# 96     4338       4055  CHESTERTON / ASSINIBOINE          111
# 97     4338       4055  CHESTERTON / ASSINIBOINE          111
# 98     4338       4055  CHESTERTON / ASSINIBOINE          111
# 99     3635       4055  CHESTERTON / ASSINIBOINE          111
#
#              longitude            latitude gps_speed trip_start_time  \
# 0   -75.72068887007863   45.35138501619038        18        14:43:00
# 1    -75.7063585478684  45.375254269303944        12        14:58:00
# 2                                                           15:12:00
# 3   -75.72068887007863   45.35138501619038        18        14:43:00
# 4    -75.7063585478684  45.375254269303944        12        14:58:00
# ..                 ...                 ...       ...             ...
# 95                                                          15:12:00
# 96  -75.72068887007863   45.35138501619038        18        14:43:00
# 97   -75.7063585478684  45.375254269303944        12        14:58:00
# 98                                                          15:12:00
# 99   -75.7181693689147   45.35002842234142        21        14:43:00
#
#    adj_sched_time adj_age           call_time stop_id start_time  \
# 0               1    0.93 2023-11-29 16:42:39     NaN        NaN
# 1              14    0.65 2023-11-29 16:42:39     NaN        NaN
# 2              28      -1 2023-11-29 16:42:39     NaN        NaN
# 3               1    0.93 2023-11-29 16:42:40     NaN        NaN
# 4              14    0.65 2023-11-29 16:42:40     NaN        NaN
# ..            ...     ...                 ...     ...        ...
# 95             28      -1 2023-11-29 16:43:10     NaN        NaN
# 96              1    1.42 2023-11-29 16:43:11     NaN        NaN
# 97             14    1.13 2023-11-29 16:43:11     NaN        NaN
# 98             28      -1 2023-11-29 16:43:11     NaN        NaN
# 99              1    0.62 2023-11-29 16:43:12     NaN        NaN
#
#     stop_sequence arrival_datetime
# 0             NaN              NaT
# 1             NaN              NaT
# 2             NaN              NaT
# 3             NaN              NaT
# 4             NaN              NaT
# ..            ...              ...
# 95            NaN              NaT
# 96            NaN              NaT
# 97            NaN              NaT
# 98            NaN              NaT
# 99            NaN              NaT
#
# [100 rows x 15 columns]

# %%
bus_info_with_times.shape
# Out:
# (4201, 15)

# %%
#TODO: Calculate Delay
# bus_info_with_times['difference'] = bus_info_with_times['arrival_datetime']-bus_info_with_times['trip_start_time']
# bus_info_with_times

bus_times_delta = []
temp = 0

for x in bus_info_with_times["adj_sched_time"]:
    x = int(x)
    temp = bus_info_with_times["call_time"] + dt.timedelta(minutes=x)
    bus_times_delta.append(temp)
    
bus_info_with_times["call_time_plus_adj"] = bus_times_delta

bus_info_with_times.head()

# bus_info_with_times['call_time_plus_adj'] = dt.datetime.combine(dt.datetime(2023, 11, 28), dt.time(seconds = bus_info_with_times['adj_sched_time'])) + bus_info_with_times['call_time']
# Out:
#   bus_stop  stop_code          stop_description route_number  \
# 0     6941       4055  CHESTERTON / ASSINIBOINE          111
# 1     6941       4055  CHESTERTON / ASSINIBOINE          111
# 2     6941       4055  CHESTERTON / ASSINIBOINE          111
# 3      572       4055  CHESTERTON / ASSINIBOINE          111
# 4      572       4055  CHESTERTON / ASSINIBOINE          111
#
#             longitude            latitude gps_speed trip_start_time  \
# 0  -75.72068887007863   45.35138501619038        18        14:43:00
# 1   -75.7063585478684  45.375254269303944        12        14:58:00
# 2                                                          15:12:00
# 3  -75.72068887007863   45.35138501619038        18        14:43:00
# 4   -75.7063585478684  45.375254269303944        12        14:58:00
#
#   adj_sched_time adj_age           call_time stop_id start_time  \
# 0              1    0.93 2023-11-29 16:42:39     NaN        NaN
# 1             14    0.65 2023-11-29 16:42:39     NaN        NaN
# 2             28      -1 2023-11-29 16:42:39     NaN        NaN
# 3              1    0.93 2023-11-29 16:42:40     NaN        NaN
# 4             14    0.65 2023-11-29 16:42:40     NaN        NaN
#
#    stop_sequence arrival_datetime  \
# 0            NaN              NaT
# 1            NaN              NaT
# 2            NaN              NaT
# 3            NaN              NaT
# 4            NaN              NaT
#
#                                   call_time_plus_adj
# 0  0      2023-11-29 16:43:39
# 1      2023-11-29 1...
# 1  0      2023-11-29 16:56:39
# 1      2023-11-29 1...
# 2  0      2023-11-29 17:10:39
# 1      2023-11-29 1...
# 3  0      2023-11-29 16:43:39
# 1      2023-11-29 1...
# 4  0      2023-11-29 16:56:39
# 1      2023-11-29 1...

# %%
bus_info_with_times.shape
# Out:
# (4201, 16)

# %%
bus_info_with_times.to_csv("OC_Transpo_Bus_Info_With_Times.csv")

# %% [markdown]
# GO TRAIN DATA

# %%
go_file = json.load(open('gotrain_output.json', encoding='utf8'))
print(go_file)
##TODO: Stuck because I can't reference any strings, only integers
go_file_new= go_file["entity"]
go_file_new
# Out:
# {
#   "header": {
#     "gtfs_realtime_version": "1.0",
#     "incrementality": "FULL_DATASET",
#     "timestamp": 1699298448
#   },
#   "entity": [
#     {
#       "id": "20231106-LW-1019",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-LW-1019",
#           "route_id": "09231223-LW",
#           "direction_id": 1,
#           "start_time": "13:17:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "667",
#           "label": "LW - Aldershot GO",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "AL",
#             "arrival": null,
#             "departure": {
#               "delay": 18,
#               "time": 1699298778,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298430,
#         "delay": 18
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-LW-1021",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-LW-1021",
#           "route_id": "09231223-LW",
#           "direction_id": 1,
#           "start_time": "14:17:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "601",
#           "label": "LW - Aldershot GO",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "EX",
#             "arrival": null,
#             "departure": {
#               "delay": 124,
#               "time": 1699298764,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "MI",
#             "arrival": null,
#             "departure": {
#               "delay": 124,
#               "time": 1699299304,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "LO",
#             "arrival": null,
#             "departure": {
#               "delay": 124,
#               "time": 1699299664,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "PO",
#             "arrival": null,
#             "departure": {
#               "delay": 124,
#               "time": 1699300084,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "CL",
#             "arrival": null,
#             "departure": {
#               "delay": 124,
#               "time": 1699300504,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "OA",
#             "arrival": null,
#             "departure": {
#               "delay": 124,
#               "time": 1699300924,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "BO",
#             "arrival": null,
#             "departure": {
#               "delay": 124,
#               "time": 1699301284,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "AP",
#             "arrival": null,
#             "departure": {
#               "delay": 124,
#               "time": 1699301644,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "BU",
#             "arrival": null,
#             "departure": {
#               "delay": 124,
#               "time": 1699302004,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "AL",
#             "arrival": null,
#             "departure": {
#               "delay": 124,
#               "time": 1699302484,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298446,
#         "delay": 124
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-LW-1022",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-LW-1022",
#           "route_id": "09231223-LW",
#           "direction_id": 0,
#           "start_time": "14:06:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "638",
#           "label": "LW - Union Station",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "BO",
#             "arrival": null,
#             "departure": {
#               "delay": 33,
#               "time": 1699298733,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "OA",
#             "arrival": null,
#             "departure": {
#               "delay": 33,
#               "time": 1699299093,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "CL",
#             "arrival": null,
#             "departure": {
#               "delay": 33,
#               "time": 1699299513,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "PO",
#             "arrival": null,
#             "departure": {
#               "delay": 33,
#               "time": 1699299873,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "LO",
#             "arrival": null,
#             "departure": {
#               "delay": 33,
#               "time": 1699300233,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "MI",
#             "arrival": null,
#             "departure": {
#               "delay": 33,
#               "time": 1699300773,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "EX",
#             "arrival": null,
#             "departure": {
#               "delay": 33,
#               "time": 1699301193,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "UN",
#             "arrival": null,
#             "departure": {
#               "delay": 33,
#               "time": 1699301733,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298445,
#         "delay": 33
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-12-12391",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-12-12391",
#           "route_id": "09231223-12",
#           "direction_id": 1,
#           "start_time": "12:42:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "8367",
#           "label": "12  - Niagara Falls",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "02646",
#             "arrival": null,
#             "departure": {
#               "delay": 653,
#               "time": 1699298453,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02404",
#             "arrival": null,
#             "departure": {
#               "delay": 653,
#               "time": 1699299173,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02408",
#             "arrival": null,
#             "departure": {
#               "delay": 653,
#               "time": 1699299773,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298445,
#         "delay": 653
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-12-12441",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-12-12441",
#           "route_id": "09231223-12",
#           "direction_id": 1,
#           "start_time": "13:42:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "8524",
#           "label": "12  - Niagara Falls",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "02406",
#             "arrival": null,
#             "departure": {
#               "delay": 319,
#               "time": 1699299199,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02621",
#             "arrival": null,
#             "departure": {
#               "delay": 319,
#               "time": 1699299739,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02402",
#             "arrival": null,
#             "departure": {
#               "delay": 319,
#               "time": 1699300939,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02646",
#             "arrival": null,
#             "departure": {
#               "delay": 319,
#               "time": 1699301719,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02404",
#             "arrival": null,
#             "departure": {
#               "delay": 319,
#               "time": 1699302439,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02408",
#             "arrival": null,
#             "departure": {
#               "delay": 319,
#               "time": 1699303039,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298445,
#         "delay": 319
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-12-12443",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-12-12443",
#           "route_id": "09231223-12",
#           "direction_id": 1,
#           "start_time": "13:57:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "8491",
#           "label": "12B - Niagara Falls",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "02404",
#             "arrival": null,
#             "departure": {
#               "delay": 67,
#               "time": 1699300387,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02408",
#             "arrival": null,
#             "departure": {
#               "delay": 67,
#               "time": 1699300987,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298445,
#         "delay": 67
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-12-12470",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-12-12470",
#           "route_id": "09231223-12",
#           "direction_id": 0,
#           "start_time": "13:22:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "8554",
#           "label": "12  - Burlington Carpool",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "02406",
#             "arrival": null,
#             "departure": {
#               "delay": 226,
#               "time": 1699298746,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02730",
#             "arrival": null,
#             "departure": {
#               "delay": 226,
#               "time": 1699299586,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00820",
#             "arrival": null,
#             "departure": {
#               "delay": 226,
#               "time": 1699300126,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00177",
#             "arrival": null,
#             "departure": {
#               "delay": 226,
#               "time": 1699300966,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00139",
#             "arrival": null,
#             "departure": {
#               "delay": 226,
#               "time": 1699301746,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298425,
#         "delay": 226
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-12-12472",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-12-12472",
#           "route_id": "09231223-12",
#           "direction_id": 0,
#           "start_time": "13:52:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "8352",
#           "label": "12B - Burlington GO",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "00820",
#             "arrival": null,
#             "departure": {
#               "delay": 259,
#               "time": 1699300039,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00177",
#             "arrival": null,
#             "departure": {
#               "delay": 259,
#               "time": 1699300879,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298445,
#         "delay": 259
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-12-12481",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-12-12481",
#           "route_id": "09231223-12",
#           "direction_id": 1,
#           "start_time": "14:40:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "8510",
#           "label": "12  - Niagara Falls",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "00139",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699299600,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00177",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699300620,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00819",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699300740,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02730",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699301760,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02406",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699302540,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02621",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303080,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02402",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699304340,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02646",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699305120,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02404",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699305840,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02408",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699306500,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298112,
#         "delay": 0
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-12-12530",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-12-12530",
#           "route_id": "09231223-12",
#           "direction_id": 0,
#           "start_time": "14:13:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "8472",
#           "label": "12  - Burlington Carpool",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "02405",
#             "arrival": null,
#             "departure": {
#               "delay": 375,
#               "time": 1699298655,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02646",
#             "arrival": null,
#             "departure": {
#               "delay": 375,
#               "time": 1699299495,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02402",
#             "arrival": null,
#             "departure": {
#               "delay": 375,
#               "time": 1699300695,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02621",
#             "arrival": null,
#             "departure": {
#               "delay": 375,
#               "time": 1699301595,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02406",
#             "arrival": null,
#             "departure": {
#               "delay": 375,
#               "time": 1699302375,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02730",
#             "arrival": null,
#             "departure": {
#               "delay": 375,
#               "time": 1699303335,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00820",
#             "arrival": null,
#             "departure": {
#               "delay": 375,
#               "time": 1699303875,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00177",
#             "arrival": null,
#             "departure": {
#               "delay": 375,
#               "time": 1699304715,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00139",
#             "arrival": null,
#             "departure": {
#               "delay": 375,
#               "time": 1699305555,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298425,
#         "delay": 375
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-12-12532",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-12-12532",
#           "route_id": "09231223-12",
#           "direction_id": 0,
#           "start_time": "14:47:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "2581",
#           "label": "12B - Burlington GO",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "02408",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699300020,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02405",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699300320,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00820",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303380,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00177",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699304220,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298445,
#         "delay": 0
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-15-15301",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-15-15301",
#           "route_id": "09231223-15",
#           "direction_id": 1,
#           "start_time": "13:33:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "8515",
#           "label": "15 - Brantford Term",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "02610",
#             "arrival": null,
#             "departure": {
#               "delay": 226,
#               "time": 1699298446,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02611",
#             "arrival": null,
#             "departure": {
#               "delay": 226,
#               "time": 1699298566,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02613",
#             "arrival": null,
#             "departure": {
#               "delay": 226,
#               "time": 1699298686,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02615",
#             "arrival": null,
#             "departure": {
#               "delay": 226,
#               "time": 1699298926,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02617",
#             "arrival": null,
#             "departure": {
#               "delay": 226,
#               "time": 1699299106,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298445,
#         "delay": 226
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-16-16421",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-16-16421",
#           "route_id": "09231223-16",
#           "direction_id": 1,
#           "start_time": "13:30:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "8305",
#           "label": "16  - Hamilton GO",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "01008",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699298820,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01013",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699298880,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01011",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699298880,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01012",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699298940,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01007",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699298940,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01014",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699299000,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00141",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699299600,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298445,
#         "delay": 0
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-16-16461",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-16-16461",
#           "route_id": "09231223-16",
#           "direction_id": 1,
#           "start_time": "14:30:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "8368",
#           "label": "16  - Hamilton GO",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "02300",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699299000,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01010",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303500,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00732",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303500,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01009",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303560,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01008",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303620,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01013",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303680,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01011",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303680,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01012",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303740,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01007",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303740,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01014",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303800,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00141",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699304400,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298425,
#         "delay": 0
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-LW-1719",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-LW-1719",
#           "route_id": "09231223-LW",
#           "direction_id": 1,
#           "start_time": "13:47:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "618",
#           "label": "LW - West Harbour GO",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "CL",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699298580,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "OA",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699299000,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "BO",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699299360,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "AP",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699299720,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "BU",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699300080,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "AL",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699300500,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "WR",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699301340,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298447,
#         "delay": 0
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-LW-1720",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-LW-1720",
#           "route_id": "09231223-LW",
#           "direction_id": 0,
#           "start_time": "13:25:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "646",
#           "label": "LW - Union Station",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "LO",
#             "arrival": null,
#             "departure": {
#               "delay": 44,
#               "time": 1699298444,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "MI",
#             "arrival": null,
#             "departure": {
#               "delay": 44,
#               "time": 1699298984,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "EX",
#             "arrival": null,
#             "departure": {
#               "delay": 44,
#               "time": 1699299404,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "UN",
#             "arrival": null,
#             "departure": {
#               "delay": 44,
#               "time": 1699299944,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298446,
#         "delay": 44
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-LW-1722",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-LW-1722",
#           "route_id": "09231223-LW",
#           "direction_id": 0,
#           "start_time": "14:25:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "680",
#           "label": "LW - Union Station",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "WR",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699298700,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "AL",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699299420,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "BU",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699299780,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "AP",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699300140,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "BO",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699300500,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "OA",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699300860,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "CL",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699301280,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "PO",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699301640,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "LO",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699302000,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "MI",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699302540,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "EX",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699302960,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "UN",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303500,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298446,
#         "delay": 0
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-17-17350",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-17-17350",
#           "route_id": "09231223-17",
#           "direction_id": 1,
#           "start_time": "11:55:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "8534",
#           "label": "17  - Hamilton GO",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "00141",
#             "arrival": null,
#             "departure": {
#               "delay": 99,
#               "time": 1699298199,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298266,
#         "delay": 8555
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-17-17390",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-17-17390",
#           "route_id": "09231223-17",
#           "direction_id": 1,
#           "start_time": "12:50:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "8505",
#           "label": "17  - Hamilton GO",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "00180",
#             "arrival": null,
#             "departure": {
#               "delay": 108,
#               "time": 1699300008,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02185",
#             "arrival": null,
#             "departure": {
#               "delay": 108,
#               "time": 1699300788,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00310",
#             "arrival": null,
#             "departure": {
#               "delay": 108,
#               "time": 1699300908,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01010",
#             "arrival": null,
#             "departure": {
#               "delay": 108,
#               "time": 1699301088,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00732",
#             "arrival": null,
#             "departure": {
#               "delay": 108,
#               "time": 1699301148,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01009",
#             "arrival": null,
#             "departure": {
#               "delay": 108,
#               "time": 1699301148,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01008",
#             "arrival": null,
#             "departure": {
#               "delay": 108,
#               "time": 1699301208,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01013",
#             "arrival": null,
#             "departure": {
#               "delay": 108,
#               "time": 1699301268,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01011",
#             "arrival": null,
#             "departure": {
#               "delay": 108,
#               "time": 1699301268,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01012",
#             "arrival": null,
#             "departure": {
#               "delay": 108,
#               "time": 1699301328,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01007",
#             "arrival": null,
#             "departure": {
#               "delay": 108,
#               "time": 1699301328,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01014",
#             "arrival": null,
#             "departure": {
#               "delay": 108,
#               "time": 1699301388,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00141",
#             "arrival": null,
#             "departure": {
#               "delay": 108,
#               "time": 1699301808,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298425,
#         "delay": 108
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-17-17401",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-17-17401",
#           "route_id": "09231223-17",
#           "direction_id": 0,
#           "start_time": "13:00:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "8366",
#           "label": "17  - U of Waterloo",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "02721",
#             "arrival": null,
#             "departure": {
#               "delay": 211,
#               "time": 1699298491,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00201",
#             "arrival": null,
#             "departure": {
#               "delay": 211,
#               "time": 1699298851,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02519",
#             "arrival": null,
#             "departure": {
#               "delay": 211,
#               "time": 1699299451,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02818",
#             "arrival": null,
#             "departure": {
#               "delay": 211,
#               "time": 1699301311,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02148",
#             "arrival": null,
#             "departure": {
#               "delay": 211,
#               "time": 1699302091,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02800",
#             "arrival": null,
#             "departure": {
#               "delay": 211,
#               "time": 1699302811,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298445,
#         "delay": 211
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-17-17430",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-17-17430",
#           "route_id": "09231223-17",
#           "direction_id": 1,
#           "start_time": "13:45:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "8492",
#           "label": "17  - Hamilton GO",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "02519",
#             "arrival": null,
#             "departure": {
#               "delay": 91,
#               "time": 1699299751,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00201",
#             "arrival": null,
#             "departure": {
#               "delay": 91,
#               "time": 1699300351,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01708",
#             "arrival": null,
#             "departure": {
#               "delay": 91,
#               "time": 1699300351,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02718",
#             "arrival": null,
#             "departure": {
#               "delay": 91,
#               "time": 1699300411,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
# ...
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00019",
#             "arrival": null,
#             "departure": {
#               "delay": 20,
#               "time": 1699302320,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00020",
#             "arrival": null,
#             "departure": {
#               "delay": 20,
#               "time": 1699302620,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "PA",
#             "arrival": null,
#             "departure": {
#               "delay": 20,
#               "time": 1699303820,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02209",
#             "arrival": null,
#             "departure": {
#               "delay": 20,
#               "time": 1699304120,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02660",
#             "arrival": null,
#             "departure": {
#               "delay": 20,
#               "time": 1699304240,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02658",
#             "arrival": null,
#             "departure": {
#               "delay": 20,
#               "time": 1699304540,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00133",
#             "arrival": null,
#             "departure": {
#               "delay": 20,
#               "time": 1699305320,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298445,
#         "delay": 20
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-94-94451",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-94-94451",
#           "route_id": "09231223-94",
#           "direction_id": 0,
#           "start_time": "14:25:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "2466",
#           "label": "94  - Pickering GO",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "00132",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699298700,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02659",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699299120,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02661",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699299420,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02208",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699299540,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "PA",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699300200,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00022",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699301100,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00019",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699301700,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02821",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699302420,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01647",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699302420,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02816",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303800,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00147",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699305000,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298446,
#         "delay": 0
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-96-96420",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-96-96420",
#           "route_id": "09231223-96",
#           "direction_id": 1,
#           "start_time": "13:30:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "2576",
#           "label": "96B - Finch Terminal",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "02816",
#             "arrival": null,
#             "departure": {
#               "delay": 326,
#               "time": 1699298426,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01648",
#             "arrival": null,
#             "departure": {
#               "delay": 326,
#               "time": 1699299926,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02772",
#             "arrival": null,
#             "departure": {
#               "delay": 326,
#               "time": 1699299926,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01662",
#             "arrival": null,
#             "departure": {
#               "delay": 326,
#               "time": 1699299926,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01653",
#             "arrival": null,
#             "departure": {
#               "delay": 326,
#               "time": 1699299986,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01660",
#             "arrival": null,
#             "departure": {
#               "delay": 326,
#               "time": 1699299986,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01655",
#             "arrival": null,
#             "departure": {
#               "delay": 326,
#               "time": 1699300046,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01650",
#             "arrival": null,
#             "departure": {
#               "delay": 326,
#               "time": 1699300046,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01661",
#             "arrival": null,
#             "departure": {
#               "delay": 326,
#               "time": 1699300106,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00736",
#             "arrival": null,
#             "departure": {
#               "delay": 326,
#               "time": 1699300526,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298445,
#         "delay": 326
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-96-96441",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-96-96441",
#           "route_id": "09231223-96",
#           "direction_id": 0,
#           "start_time": "14:05:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "8508",
#           "label": "96B - DC Oshawa GO",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "02816",
#             "arrival": null,
#             "departure": {
#               "delay": 291,
#               "time": 1699299291,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00161",
#             "arrival": null,
#             "departure": {
#               "delay": 291,
#               "time": 1699300311,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00031",
#             "arrival": null,
#             "departure": {
#               "delay": 291,
#               "time": 1699301091,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02573",
#             "arrival": null,
#             "departure": {
#               "delay": 291,
#               "time": 1699301511,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00159",
#             "arrival": null,
#             "departure": {
#               "delay": 291,
#               "time": 1699301691,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298425,
#         "delay": 291
#       },
#       "vehicle": null,
#       "alert": null
#     },
#     {
#       "id": "20231106-96-96450",
#       "is_deleted": false,
#       "trip_update": {
#         "trip": {
#           "trip_id": "20231106-96-96450",
#           "route_id": "09231223-96",
#           "direction_id": 1,
#           "start_time": "14:30:00",
#           "start_date": "20231106",
#           "schedule_relationship": "SCHEDULED"
#         },
#         "vehicle": {
#           "id": "8300",
#           "label": "96B - Finch Terminal",
#           "license_plate": ""
#         },
#         "stop_time_update": [
#           {
#             "stop_id": "00159",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699299000,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02572",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699299120,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00031",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699299480,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00161",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699300200,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00723",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699301640,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02816",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699301700,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01648",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303200,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "02772",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303200,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01662",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303200,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01653",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303260,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01660",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303260,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01655",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303320,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01650",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303320,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "01661",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303380,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           },
#           {
#             "stop_id": "00736",
#             "arrival": null,
#             "departure": {
#               "delay": 0,
#               "time": 1699303800,
#               "uncertainty": 0
#             },
#             "schedule_relationship": "SCHEDULED"
#           }
#         ],
#         "timestamp": 1699298425,
#         "delay": 0
#       },
#       "vehicle": null,
#       "alert": null
#     }
#   ]
# }
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 4
#       2 print(go_file)
#       3 ##TODO: Stuck because I can't reference any strings, only integers
# ----> 4 go_file_new= go_file["entity"]
#       5 go_file_new
#
# TypeError: string indices must be integers

# %% [markdown]
# VANCOUVER BUS DATA (TRANSLINK)

# %%
#VANCOUVER
tl_file= 'translink_data.xml'

# Parse the XML file
tree = ET.parse(tl_file)
root = tree.getroot()

# Extract data from XML and create a list of dictionaries
tl_bus_data_list = []
for item in root.findall('Bus'):
    data = {}
    data['VehicleNo'] = item.find('VehicleNo').text
    data['TripId'] = item.find('TripId').text
    data['RouteNo'] = item.find('RouteNo').text
    data['Direction'] = item.find('Direction').text
    data['Destination'] = item.find('Destination').text
    data['Pattern'] = item.find('Pattern').text
    data['Latitude'] = item.find('Latitude').text
    data['Longitude'] = item.find('Longitude').text
    data['RecordedTime'] = item.find('RecordedTime').text
    
    tl_bus_data_list.append(data)

# Create a DataFrame from the list of dictionaries
tl_bus_df = pd.DataFrame(tl_bus_data_list)
tl_bus_df
#TODO: times but no dates...confused on how to get delay data from this
# Out:
#     VehicleNo    TripId RouteNo Direction     Destination Pattern   Latitude  \
# 0       12001  13539101     049      WEST             UBC     WB1  49.222067
# 1       12003  13590009     049      EAST   METROTOWN STN     EB1  49.247100
# 2       12007  13590007     049      EAST   METROTOWN STN     EB1  49.226467
# 3       12008  13539007     049      EAST   METROTOWN STN     EB1  49.225950
# 4       12010  13590006     049      EAST   METROTOWN STN     EB1  49.226900
# ..        ...       ...     ...       ...             ...     ...        ...
# 777      9784  13537178     028     NORTH     PHIBBS EXCH      N1  49.236233
# 778      9786  13556614     230     SOUTH   LONSDALE QUAY      S1  49.344833
# 779      9787  13556791     232      EAST     PHIBBS EXCH      E1  49.312200
# 780      9788  13556543     230     NORTH  UPPER LONSDALE      N1  49.320950
# 781      9797  13569762     403     NORTH  BRIDGEPORT STN    NB1A  49.133467
#
#        Longitude RecordedTime
# 0    -123.024783  10:38:27 am
# 1    -123.232083  10:38:48 am
# 2    -123.005067  10:34:41 am
# 3    -123.112367  10:38:45 am
# 4    -123.006117  10:24:59 am
# ..           ...          ...
# 777  -123.027667  10:38:22 am
# 778  -123.073733  10:38:14 am
# 779  -123.040417  10:38:56 am
# 780  -123.072217  10:39:08 am
# 781  -123.100450  10:38:12 am
#
# [782 rows x 9 columns]

# %% [markdown]
# Montreal

# %%
montreal_raw = pd.read_csv("STM Incidents métro.csv")

# %%
montreal_raw.head()
# Out:
#   Numero d'incident Type d'incident Cause primaire Cause secondaire  \
# 0         S01011901               S         Autres           Autres
# 1         S01011902               S         Autres           Autres
# 2         S01011903               S         Autres           Autres
# 3         S01011904               S         Autres           Autres
# 4         S01011905               S         Autres           Autres
#
#     Symptome         Ligne Numéro de tournée Heure de l'incident  \
# 0  Clientèle  Ligne orange                 #               02:56
# 1  Clientèle  Ligne orange                 #               02:56
# 2  Clientèle   Ligne verte                 #               03:35
# 3  Clientèle   Ligne verte                 #               04:56
# 4  Clientèle   Ligne verte                 #               05:25
#
#   Heure de reprise Incident en minutes  ... Porte Urgence métro CAT  \
# 0            03:32     02 min et moins  ...     0             0   0
# 1            03:42     02 min et moins  ...     0             0   0
# 2            04:41     02 min et moins  ...     0             0   0
# 3            05:36     02 min et moins  ...     0             0   0
# 4            05:54     02 min et moins  ...     0             0   0
#
#   Évacuation  Année civile  Année civile/mois  Mois calendrier  Jour du mois  \
# 0          #          2019            2019-01                1             1
# 1          #          2019            2019-01                1             1
# 2          #          2019            2019-01                1             1
# 3          #          2019            2019-01                1             1
# 4          #          2019            2019-01                1             1
#
#    Jour de la semaine Jour calendaire
# 0                   2      2019-01-01
# 1                   2      2019-01-01
# 2                   2      2019-01-01
# 3                   2      2019-01-01
# 4                   2      2019-01-01
#
# [5 rows x 26 columns]

# %%
print(montreal_raw["Heure de l\'incident"])
# Out:
# 0        02:56
# 1        02:56
# 2        03:35
# 3        04:56
# 4        05:25
#          ...
# 30789    19:02
# 30790    20:38
# 30791    21:59
# 30792    23:43
# 30793    24:09
# Name: Heure de l'incident, Length: 30794, dtype: object

# %%
montreal_raw['Heure de l\'incident'] = montreal_raw['Heure de l\'incident'].apply(lambda x: x if int(x[:2]) < 24 else str((int(x[:2]) - 24)) + x[2:])

montreal_raw["Heure de l\'incident"]
# Out:
# 0        02:56
# 1        02:56
# 2        03:35
# 3        04:56
# 4        05:25
#          ...
# 30789    19:02
# 30790    20:38
# 30791    21:59
# 30792    23:43
# 30793     0:09
# Name: Heure de l'incident, Length: 30794, dtype: object

# %%
montreal_raw["time_dt"] = pd.to_datetime(montreal_raw["Jour calendaire"] + " " + montreal_raw["Heure de l\'incident"], format="mixed", dayfirst=True)

# %%
montreal_raw.head()
# Out:
#   Numero d'incident Type d'incident Cause primaire Cause secondaire  \
# 0         S01011901               S         Autres           Autres
# 1         S01011902               S         Autres           Autres
# 2         S01011903               S         Autres           Autres
# 3         S01011904               S         Autres           Autres
# 4         S01011905               S         Autres           Autres
#
#     Symptome         Ligne Numéro de tournée Heure de l'incident  \
# 0  Clientèle  Ligne orange                 #               02:56
# 1  Clientèle  Ligne orange                 #               02:56
# 2  Clientèle   Ligne verte                 #               03:35
# 3  Clientèle   Ligne verte                 #               04:56
# 4  Clientèle   Ligne verte                 #               05:25
#
#   Heure de reprise Incident en minutes  ... Urgence métro CAT Évacuation  \
# 0            03:32     02 min et moins  ...             0   0          #
# 1            03:42     02 min et moins  ...             0   0          #
# 2            04:41     02 min et moins  ...             0   0          #
# 3            05:36     02 min et moins  ...             0   0          #
# 4            05:54     02 min et moins  ...             0   0          #
#
#   Année civile  Année civile/mois  Mois calendrier  Jour du mois  \
# 0         2019            2019-01                1             1
# 1         2019            2019-01                1             1
# 2         2019            2019-01                1             1
# 3         2019            2019-01                1             1
# 4         2019            2019-01                1             1
#
#    Jour de la semaine  Jour calendaire             time_dt
# 0                   2       2019-01-01 2019-01-01 02:56:00
# 1                   2       2019-01-01 2019-01-01 02:56:00
# 2                   2       2019-01-01 2019-01-01 03:35:00
# 3                   2       2019-01-01 2019-01-01 04:56:00
# 4                   2       2019-01-01 2019-01-01 05:25:00
#
# [5 rows x 27 columns]

# %%
montreal_raw.drop(columns=["Jour calendaire", 'Numero d\'incident'])
# Out:
#       Type d'incident Cause primaire       Cause secondaire  \
# 0                   S         Autres                 Autres
# 1                   S         Autres                 Autres
# 2                   S         Autres                 Autres
# 3                   S         Autres                 Autres
# 4                   S         Autres                 Autres
# ...               ...            ...                    ...
# 30789               T      Clientèle      Méfait volontaire
# 30790               T      Clientèle      Méfait volontaire
# 30791               T      Clientèle      Méfait volontaire
# 30792               T      Clientèle  Nuisance involontaire
# 30793               T         Autres        Causes externes
#
#                                  Symptome         Ligne Numéro de tournée  \
# 0                               Clientèle  Ligne orange                 #
# 1                               Clientèle  Ligne orange                 #
# 2                               Clientèle   Ligne verte                 #
# 3                               Clientèle   Ligne verte                 #
# 4                               Clientèle   Ligne verte                 #
# ...                                   ...           ...               ...
# 30789                           Clientèle   Ligne verte                 #
# 30790  Feu, fumée, odeur, produit, etc...  Ligne orange                 6
# 30791  Feu, fumée, odeur, produit, etc...   Ligne verte                13
# 30792                    Matériel roulant   Ligne verte                 1
# 30793                   Équipements fixes  Ligne orange                 #
#
#       Heure de l'incident Heure de reprise Incident en minutes Véhicule  ...  \
# 0                   02:56            03:32     02 min et moins        #  ...
# 1                   02:56            03:42     02 min et moins        #  ...
# 2                   03:35            04:41     02 min et moins        #  ...
# 3                   04:56            05:36     02 min et moins        #  ...
# 4                   05:25            05:54     02 min et moins        #  ...
# ...                   ...              ...                 ...      ...  ...
# 30789               19:02            19:02     02 min et moins    79600  ...
# 30790               20:38            20:38     02 min et moins        #  ...
# 30791               21:59            22:03         03 à 04 min        #  ...
# 30792               23:43            23:45     02 min et moins    10653  ...
# 30793                0:09            24:13         03 à 04 min        #  ...
#
#       Porte Urgence métro CAT  Évacuation  Année civile  Année civile/mois  \
# 0         0             0   0           #          2019            2019-01
# 1         0             0   0           #          2019            2019-01
# 2         0             0   0           #          2019            2019-01
# 3         0             0   0           #          2019            2019-01
# 4         0             0   0           #          2019            2019-01
# ...     ...           ...  ..         ...           ...                ...
# 30789     0             0   0           #          2022            2022-12
# 30790     0             0   0           #          2022            2022-12
# 30791     0             0   0           #          2022            2022-12
# 30792     1             0   0           #          2022            2022-12
# 30793     0             0   1           #          2022            2022-12
#
#        Mois calendrier  Jour du mois Jour de la semaine             time_dt
# 0                    1             1                  2 2019-01-01 02:56:00
# 1                    1             1                  2 2019-01-01 02:56:00
# 2                    1             1                  2 2019-01-01 03:35:00
# 3                    1             1                  2 2019-01-01 04:56:00
# 4                    1             1                  2 2019-01-01 05:25:00
# ...                ...           ...                ...                 ...
# 30789               12            31                  6 2022-12-31 19:02:00
# 30790               12            31                  6 2022-12-31 20:38:00
# 30791               12            31                  6 2022-12-31 21:59:00
# 30792               12            31                  6 2022-12-31 23:43:00
# 30793               12            31                  6 2023-01-01 00:09:00
#
# [30794 rows x 25 columns]

# %%
montreal_raw["Incident en minutes"].unique()
# Out:
# array(['02 min et moins', '03 à 04 min', '10 à 14 min', '05 à 09 min',
#        '25 à 29 min', '15 à 19 min', '30 min et plus', '20 à 24 min'],
#       dtype=object)

# %%
delay_row = []

for row in montreal_raw["Incident en minutes"]:
    if row == "02 min et moins":
        delay_row.append(2)
    elif row == "03 à 04 min":
        delay_row.append(4)
    elif row == "05 à 09 min":
        delay_row.append(9)
    elif row == "10 à 14 min":
        delay_row.append(14)
    elif row == "15 à 19 min":
        delay_row.append(19)
    elif row == "20 à 24 min":
        delay_row.append(24)
    elif row == "25 à 29 min":
        delay_row.append(29)
    elif row == "30 min et plus":
        delay_row.append(30)
    else:
        delay_row.append(0)
montreal_raw["delay"] = delay_row

# %%
montreal_raw["delay"].value_counts()
# Out:
# delay
# 2     22130
# 4      4392
# 9      2945
# 14      612
# 30      348
# 19      195
# 24       97
# 29       75
# Name: count, dtype: int64

# %%
montreal_raw.head()
# Out:
#   Numero d'incident Type d'incident Cause primaire Cause secondaire  \
# 0         S01011901               S         Autres           Autres
# 1         S01011902               S         Autres           Autres
# 2         S01011903               S         Autres           Autres
# 3         S01011904               S         Autres           Autres
# 4         S01011905               S         Autres           Autres
#
#     Symptome         Ligne Numéro de tournée Heure de l'incident  \
# 0  Clientèle  Ligne orange                 #               02:56
# 1  Clientèle  Ligne orange                 #               02:56
# 2  Clientèle   Ligne verte                 #               03:35
# 3  Clientèle   Ligne verte                 #               04:56
# 4  Clientèle   Ligne verte                 #               05:25
#
#   Heure de reprise Incident en minutes  ... CAT Évacuation Année civile  \
# 0            03:32     02 min et moins  ...   0          #         2019
# 1            03:42     02 min et moins  ...   0          #         2019
# 2            04:41     02 min et moins  ...   0          #         2019
# 3            05:36     02 min et moins  ...   0          #         2019
# 4            05:54     02 min et moins  ...   0          #         2019
#
#   Année civile/mois  Mois calendrier  Jour du mois  Jour de la semaine  \
# 0           2019-01                1             1                   2
# 1           2019-01                1             1                   2
# 2           2019-01                1             1                   2
# 3           2019-01                1             1                   2
# 4           2019-01                1             1                   2
#
#    Jour calendaire             time_dt delay
# 0       2019-01-01 2019-01-01 02:56:00     2
# 1       2019-01-01 2019-01-01 02:56:00     2
# 2       2019-01-01 2019-01-01 03:35:00     2
# 3       2019-01-01 2019-01-01 04:56:00     2
# 4       2019-01-01 2019-01-01 05:25:00     2
#
# [5 rows x 28 columns]

# %%
montreal_raw.to_csv("stm_df.csv", index=None)
