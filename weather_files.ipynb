# %% [markdown]
# ## Calgary Weather

# %%
# Import 3rd party libraries
import os
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt

# %%
calgary_weather_files = [os.path.join('Calgary_intl_weather', file) for file in os.listdir('Calgary_intl_weather') if 'en_climate_daily_AB' in file]

# Loop through the selected weather files, create individual dataframes for each sheet, and add dfs to a list 
dfs=[]
for file in calgary_weather_files:
    temp_df = pd.read_csv(file)
    dfs.append(temp_df)
    
# Concatenate all individual DataFrames from the list into a single DataFrame
calgary_weather = pd.concat(dfs, ignore_index=True)
calgary_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Longitude (x)              730 non-null    float64
#  1   Latitude (y)               730 non-null    float64
#  2   Station Name               730 non-null    object
#  3   Climate ID                 730 non-null    int64
#  4   Date/Time                  730 non-null    object
#  5   Year                       730 non-null    int64
#  6   Month                      730 non-null    int64
#  7   Day                        730 non-null    int64
#  8   Data Quality               0 non-null      float64
#  9   Max Temp (°C)              719 non-null    float64
#  10  Max Temp Flag              22 non-null     object
#  11  Min Temp (°C)              712 non-null    float64
#  12  Min Temp Flag              22 non-null     object
# ...

# %%
# #Viwing weather data
# csv_file_path = os.path.join('Calgary_intl_weather','en_climate_daily_AB_3031094_2019_P1D.csv')
# calgary_weather = pd.read_csv(csv_file_path)
# calgary_weather.info()

# %%
#Removing categories with no data
calgary_weather_reduced = calgary_weather.drop(columns=['Data Quality', 'Total Rain (mm)','Total Rain Flag','Total Snow (cm)', 'Total Snow Flag', 'Snow on Grnd Flag'])

# %%
#Check to make sure data is complete and makes sense
calgary_weather_reduced.plot(x='Date/Time', y='Total Precip (mm)')
plt.xticks(rotation=45)
plt.show()

# %%
#Convert combined dataframe into a csv 
calgary_weather_reduced.to_csv('calgary_weather_simplified.csv', index='False')

# %% [markdown]
# ## Montreal Weather

# %%
#Create a list of file names
montreal_weather_files = [os.path.join('Montreal_weather', file) for file in os.listdir('Montreal_weather') if 'en_climate_daily_QC_7024745' in file]

# Loop through the selected weather files, create individual dataframes for each sheet, and add dfs to a list 
dfs=[]
for file in montreal_weather_files:
    temp_df = pd.read_csv(file)
    dfs.append(temp_df)
    
# Concatenate all individual DataFrames from the list into a single DataFrame
montreal_weather = pd.concat(dfs, ignore_index=True)

# %%
montreal_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Longitude (x)              1461 non-null   float64
#  1   Latitude (y)               1461 non-null   float64
#  2   Station Name               1461 non-null   object
#  3   Climate ID                 1461 non-null   int64
#  4   Date/Time                  1461 non-null   object
#  5   Year                       1461 non-null   int64
#  6   Month                      1461 non-null   int64
#  7   Day                        1461 non-null   int64
#  8   Data Quality               0 non-null      float64
#  9   Max Temp (°C)              1449 non-null   float64
#  10  Max Temp Flag              9 non-null      object
#  11  Min Temp (°C)              1449 non-null   float64
#  12  Min Temp Flag              9 non-null      object
# ...

# %%
#Remove columns with no info and sort Date/Time to avoid graphs with data in the wrong order
montreal_weather_reduced = montreal_weather.drop(columns=['Data Quality', 'Total Rain (mm)','Total Rain Flag','Total Snow (cm)', 'Total Snow Flag', 'Snow on Grnd Flag']).sort_values(by='Date/Time')

# %%
#Verify that data is complete and makes sense
montreal_weather_reduced.plot(x='Date/Time', y='Total Precip (mm)')
plt.xticks(rotation=45)
plt.show()

# %%
#Convert combined dataframe into a csv 
montreal_weather_reduced.to_csv('montreal_weather_simplified.csv', index='False')

# %% [markdown]
# ## Toronto Weather Data

# %%
#Create a list of file names
toronto_weather_files = [os.path.join('Toronto_cc_weather', file) for file in os.listdir('Toronto_cc_weather') if 'en_climate_daily_ON_6158359' in file]

# Loop through the selected weather files, create individual dataframes for each sheet, and add dfs to a list 
dfs=[]
for file in toronto_weather_files:
    temp_df = pd.read_csv(file)
    dfs.append(temp_df)
    
# Concatenate all individual DataFrames from the list into a single DataFrame
toronto_weather = pd.concat(dfs, ignore_index=True)

# %%
toronto_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18616 entries, 0 to 18615
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Longitude (x)              18616 non-null  float64
#  1   Latitude (y)               18616 non-null  float64
#  2   Station Name               18616 non-null  object
#  3   Climate ID                 18616 non-null  int64
#  4   Date/Time                  18616 non-null  object
#  5   Year                       18616 non-null  int64
#  6   Month                      18616 non-null  int64
#  7   Day                        18616 non-null  int64
#  8   Data Quality               0 non-null      float64
#  9   Max Temp (°C)              17548 non-null  float64
#  10  Max Temp Flag              697 non-null    object
#  11  Min Temp (°C)              17550 non-null  float64
#  12  Min Temp Flag              697 non-null    object
# ...

# %%
#Remove columns with no info and sort Date/Time to avoid graphs with data in the wrong order
toronto_weather_reduced = toronto_weather.drop(columns=['Data Quality', 'Total Rain (mm)','Total Rain Flag','Total Snow (cm)', 'Total Snow Flag', 'Snow on Grnd Flag']).sort_values(by='Date/Time')

# %%
#Verify that data is complete and makes sense
toronto_weather_reduced.plot(x='Date/Time', y='Total Precip (mm)')
plt.xticks(rotation=45)
plt.show()

# %%
#Convert combined dataframe into a csv 
toronto_weather_reduced.to_csv('toronto_weather_simplified.csv', index='False')
